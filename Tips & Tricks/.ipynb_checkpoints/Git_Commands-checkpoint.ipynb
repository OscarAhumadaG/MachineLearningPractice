# %% [markdown]
# ## Git Commands

# %% [markdown]
# ```bash
# git add .
# ```
#
# ```bash
# git branch -M main
# ```
#
# ```bash
# git push -u origin main
# ```
#
# ```bash
# git commit -m "message"
# ```
#
# ```bash
# git commit -a
# ```
